# %%
#importing the libraries
import numpy as py
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)          #if male is '0' -then female is '1'
dataset                                                  #if smoker is '0'- then smoker is'1'  so use(drop_first=True)
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['mse','mae','friedman_mse'],
           'max_features':['auto','sqrt','log2'],
           'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# C:\Users\ELCOT\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:  1.4min finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
# ...

# %%
re=grid.cv_results_
print("The r_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The r_score value for best parameter {'criterion': 'mse', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.013439      0.003420         0.004037        0.004349
# 1        0.007405      0.003792         0.010755        0.000957
# 2        0.010769      0.000933         0.003356        0.003414
# 3        0.007398      0.003791         0.004713        0.003788
# 4        0.010092      0.000025         0.002029        0.000006
# 5        0.007403      0.003794         0.003372        0.004769
# 6        0.171029      0.021808         0.041052        0.056630
# 7        0.171922      0.013675         0.010081        0.000018
# 8        0.168291      0.003383         0.007408        0.005306
# 9        0.117642      0.061696         0.041095        0.056689
# 10       0.077794      0.058833         0.073997        0.046882
# 11       0.031570      0.000953         0.107492        0.009342
# 12       0.011447      0.000963         0.006047        0.004357
# ...

# %%
age_input=int(input("Enter age:"))
BMI_input=(input("Enter BMI:"))
children_input=int(input("Enter Children:"))
sex_male_input=int(input("Enter Sex_Male 0 or 1:"))
Smoker_input=int(input("Enter Smoker_yes 0 or 1:"))
# Out:
# Enter age:44
# Enter BMI:200
# Enter Children:5
# Enter Sex_Male 0 or 1:1
# Enter Smoker_yes 0 or 1:0

# %%
Future_prediction=grid.predict([[age_input,BMI_input,children_input,sex_male_input,Smoker_input]])

# %%
Future_prediction
# Out:
# array([11033.6617])
